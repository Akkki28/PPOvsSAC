# %% [markdown]
# <a href="https://colab.research.google.com/github/Akkki28/PPOvsSAC/blob/main/PPOvsSAC_Slide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
# !pip install gymnasium_robotics
# Out:
# Collecting gymnasium_robotics
#   Downloading gymnasium_robotics-1.3.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting mujoco<3.2.0,>=2.2.0 (from gymnasium_robotics)
#   Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.0.0)
# Collecting PettingZoo>=1.23.0 (from gymnasium_robotics)
#   Downloading pettingzoo-1.24.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: Jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (3.1.5)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (2.37.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.0.3->gymnasium_robotics) (3.0.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.12.0)
# Collecting glfw (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics)
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.1.9)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->gymnasium_robotics) (11.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.21.0)
# Downloading gymnasium_robotics-1.3.1-py3-none-any.whl (26.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 17.3 MB/s eta 0:00:00
# Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 25.3 MB/s eta 0:00:00
# Downloading pettingzoo-1.24.3-py3-none-any.whl (847 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 847.8/847.8 kB 36.3 MB/s eta 0:00:00
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: glfw, PettingZoo, mujoco, gymnasium_robotics
# Successfully installed PettingZoo-1.24.3 glfw-2.8.0 gymnasium_robotics-1.3.1 mujoco-3.1.6

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 6.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.5.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO,SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_dir = "./logs_PPO/"
os.makedirs(log_dir, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class SaveOnBestTrainingRewardCallback(BaseCallback):
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

gym.register_envs(gymnasium_robotics)
env = gym.make('FetchSlideDense-v3')
env = Monitor(env, log_dir)
vec_env = make_vec_env(lambda: env, n_envs=1)

model1 = PPO("MultiInputPolicy",vec_env, verbose=1)
model1.learn(total_timesteps=25000,callback=callback)
model1.save("ppo")
# Out:
# Using cuda device
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -31.60
# Saving new best model to ./logs_PPO/best_model.zip
# Num timesteps: 2000
# Best mean reward: -31.60 - Last mean reward per episode: -32.32
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 223      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -31.60 - Last mean reward per episode: -31.92
# Num timesteps: 4000
# Best mean reward: -31.60 - Last mean reward per episode: -32.46
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -32.5        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0069485977 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.00271      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.45         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00509     |
# |    std                  | 0.99         |
# |    value_loss           | 17           |
# ------------------------------------------
# Num timesteps: 5000
# Best mean reward: -31.60 - Last mean reward per episode: -32.48
# Num timesteps: 6000
# Best mean reward: -31.60 - Last mean reward per episode: -32.82
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -33          |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 3            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0060108127 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.16         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.985        |
# |    value_loss           | 15           |
# ------------------------------------------
# Num timesteps: 7000
# Best mean reward: -31.60 - Last mean reward per episode: -32.73
# Num timesteps: 8000
# Best mean reward: -31.60 - Last mean reward per episode: -33.10
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -33.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 4           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004696601 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.47        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00269    |
# |    std                  | 0.984       |
# |    value_loss           | 12.9        |
# -----------------------------------------
# Num timesteps: 9000
# Best mean reward: -31.60 - Last mean reward per episode: -32.64
# Num timesteps: 10000
# Best mean reward: -31.60 - Last mean reward per episode: -32.45
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -32.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 5           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005498523 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.61       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00218    |
# |    std                  | 0.982       |
# |    value_loss           | 8.38        |
# -----------------------------------------
# Num timesteps: 11000
# Best mean reward: -31.60 - Last mean reward per episode: -32.53
# Num timesteps: 12000
# Best mean reward: -31.60 - Last mean reward per episode: -32.99
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -32.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 6            |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0095606465 |
# |    clip_fraction        | 0.0784       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.59        |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.997        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00772     |
# |    std                  | 0.978        |
# |    value_loss           | 4.88         |
# ------------------------------------------
# Num timesteps: 13000
# Best mean reward: -31.60 - Last mean reward per episode: -33.21
# Num timesteps: 14000
# Best mean reward: -31.60 - Last mean reward per episode: -33.86
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -34         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 7           |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009412155 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.68        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.97        |
# |    value_loss           | 6.1         |
# -----------------------------------------
# Num timesteps: 15000
# Best mean reward: -31.60 - Last mean reward per episode: -34.25
# Num timesteps: 16000
# Best mean reward: -31.60 - Last mean reward per episode: -34.18
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -34.2      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 197        |
# |    iterations           | 8          |
# |    time_elapsed         | 82         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01385201 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.53      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.44       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.962      |
# |    value_loss           | 4.75       |
# ----------------------------------------
# Num timesteps: 17000
# Best mean reward: -31.60 - Last mean reward per episode: -33.64
# Num timesteps: 18000
# Best mean reward: -31.60 - Last mean reward per episode: -33.65
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -33.5       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 9           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013434333 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.957       |
# |    value_loss           | 2.95        |
# -----------------------------------------
# Num timesteps: 19000
# Best mean reward: -31.60 - Last mean reward per episode: -33.37
# Num timesteps: 20000
# Best mean reward: -31.60 - Last mean reward per episode: -33.78
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -33.9       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 10          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010029638 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.872       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.949       |
# |    value_loss           | 2.18        |
# -----------------------------------------
# Num timesteps: 21000
# Best mean reward: -31.60 - Last mean reward per episode: -33.97
# Num timesteps: 22000
# Best mean reward: -31.60 - Last mean reward per episode: -34.53
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -34.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 11          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014267068 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.91        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.938       |
# |    value_loss           | 2.52        |
# -----------------------------------------
# Num timesteps: 23000
# Best mean reward: -31.60 - Last mean reward per episode: -34.43
# Num timesteps: 24000
# Best mean reward: -31.60 - Last mean reward per episode: -34.10
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -33.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 195          |
# |    iterations           | 12           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0138248075 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.683        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0183      |
# |    std                  | 0.926        |
# |    value_loss           | 1.6          |
# ------------------------------------------
# Num timesteps: 25000
# Best mean reward: -31.60 - Last mean reward per episode: -33.52
# Num timesteps: 26000
# Best mean reward: -31.60 - Last mean reward per episode: -33.23
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -33.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 13          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011625586 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.482       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.921       |
# |    value_loss           | 1.54        |
# -----------------------------------------

# %%
log_dir2 = "./logs_SAC/"
os.makedirs(log_dir2, exist_ok=True)

# %%
callback2 = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir2)

env2 = gym.make('FetchSlideDense-v3')
env2 = Monitor(env2, log_dir2)
vec_env2 = make_vec_env(lambda: env2, n_envs=1)

model2 = SAC("MultiInputPolicy",vec_env2, verbose=1)
model2.learn(total_timesteps=25000,callback=callback2)
model2.save("sac")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -30.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 93       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -5.13    |
# |    critic_loss     | 0.0771   |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 76       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 0.0613   |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.601   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 71       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | -7.28    |
# |    critic_loss     | 0.0651   |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 67       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -8.27    |
# |    critic_loss     | 0.0287   |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -31.88
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 65       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -9.36    |
# |    critic_loss     | 0.0299   |
# |    ent_coef        | 0.764    |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 64       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.032    |
# |    ent_coef        | 0.719    |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 64       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.0224   |
# |    ent_coef        | 0.677    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 62       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.0256   |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -3.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 62       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.0346   |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -3.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# Num timesteps: 2000
# Best mean reward: -31.88 - Last mean reward per episode: -32.12
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 62       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.0179   |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -3.85    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 62       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.019    |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -4.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 62       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.0206   |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -4.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 62       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 0.0274   |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -5.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 62       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.0195   |
# |    ent_coef        | 0.445    |
# |    ent_coef_loss   | -5.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -31.88 - Last mean reward per episode: -32.82
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 61       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.0173   |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -5.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 61       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.013    |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | -6.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 61       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.0177   |
# |    ent_coef        | 0.372    |
# |    ent_coef_loss   | -6.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 61       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.00831  |
# |    ent_coef        | 0.35     |
# |    ent_coef_loss   | -7.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 61       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0104   |
# |    ent_coef        | 0.33     |
# |    ent_coef_loss   | -7.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3699     |
# ---------------------------------
# Num timesteps: 4000
# Best mean reward: -31.88 - Last mean reward per episode: -32.98
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 61       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.00877  |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -7.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 61       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.0122   |
# |    ent_coef        | 0.292    |
# |    ent_coef_loss   | -8.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 61       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.00944  |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -8.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 61       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.0117   |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | -9.06    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 61       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.00963  |
# |    ent_coef        | 0.244    |
# |    ent_coef_loss   | -9.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# Num timesteps: 5000
# Best mean reward: -31.88 - Last mean reward per episode: -33.12
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 61       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.00969  |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | -9.92    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 61       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.0073   |
# |    ent_coef        | 0.217    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 60       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.00705  |
# |    ent_coef        | 0.204    |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 60       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.00851  |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 60       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.00576  |
# |    ent_coef        | 0.181    |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5699     |
# ---------------------------------
# Num timesteps: 6000
# Best mean reward: -31.88 - Last mean reward per episode: -33.72
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 60       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.00777  |
# |    ent_coef        | 0.171    |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 60       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.00446  |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -12.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 60       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.00683  |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 60       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.00383  |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 60       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 0.00587  |
# |    ent_coef        | 0.134    |
# |    ent_coef_loss   | -13.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# Num timesteps: 7000
# Best mean reward: -31.88 - Last mean reward per episode: -33.65
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 60       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.00605  |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 60       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.00567  |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | -14.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 60       |
# |    time_elapsed    | 121      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | -9.37    |
# |    critic_loss     | 0.00707  |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 60       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -8.87    |
# |    critic_loss     | 0.00539  |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 60       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -8.24    |
# |    critic_loss     | 0.00475  |
# |    ent_coef        | 0.0995   |
# |    ent_coef_loss   | -15.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7699     |
# ---------------------------------
# Num timesteps: 8000
# Best mean reward: -31.88 - Last mean reward per episode: -33.25
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 60       |
# |    time_elapsed    | 131      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -7.84    |
# |    critic_loss     | 0.00523  |
# |    ent_coef        | 0.0937   |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 60       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | -7.36    |
# |    critic_loss     | 0.00622  |
# |    ent_coef        | 0.0883   |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 60       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -6.83    |
# |    critic_loss     | 0.0041   |
# |    ent_coef        | 0.0831   |
# |    ent_coef_loss   | -16.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 60       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | -6.39    |
# |    critic_loss     | 0.00923  |
# |    ent_coef        | 0.0783   |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 60       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -5.87    |
# |    critic_loss     | 0.00503  |
# |    ent_coef        | 0.0738   |
# |    ent_coef_loss   | -17.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# Num timesteps: 9000
# Best mean reward: -31.88 - Last mean reward per episode: -32.93
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 60       |
# |    time_elapsed    | 148      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -5.55    |
# |    critic_loss     | 0.00798  |
# |    ent_coef        | 0.0695   |
# |    ent_coef_loss   | -17.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 60       |
# |    time_elapsed    | 151      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -4.52    |
# |    critic_loss     | 0.0066   |
# |    ent_coef        | 0.0655   |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 60       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | -4.22    |
# |    critic_loss     | 0.00657  |
# |    ent_coef        | 0.0617   |
# |    ent_coef_loss   | -18.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 60       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -3.57    |
# |    critic_loss     | 0.00644  |
# |    ent_coef        | 0.0581   |
# |    ent_coef_loss   | -18.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 60       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | -3.08    |
# |    critic_loss     | 0.0068   |
# |    ent_coef        | 0.0548   |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9699     |
# ---------------------------------
# Num timesteps: 10000
# Best mean reward: -31.88 - Last mean reward per episode: -32.64
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 60       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -2.49    |
# |    critic_loss     | 0.0047   |
# |    ent_coef        | 0.0516   |
# |    ent_coef_loss   | -19.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 60       |
# |    time_elapsed    | 167      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -1.78    |
# |    critic_loss     | 0.00722  |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | -19.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 60       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -1.15    |
# |    critic_loss     | 0.0136   |
# |    ent_coef        | 0.0458   |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 60       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 10600    |
# | train/             |          |
# |    actor_loss      | -1.09    |
# |    critic_loss     | 0.00529  |
# |    ent_coef        | 0.0432   |
# |    ent_coef_loss   | -20.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 60       |
# |    time_elapsed    | 177      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -0.821   |
# |    critic_loss     | 0.00755  |
# |    ent_coef        | 0.0407   |
# |    ent_coef_loss   | -21.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10699    |
# ---------------------------------
# Num timesteps: 11000
# Best mean reward: -31.88 - Last mean reward per episode: -31.98
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 60       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | 0.218    |
# |    critic_loss     | 0.0149   |
# |    ent_coef        | 0.0383   |
# |    ent_coef_loss   | -21.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 60       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | 1.03     |
# |    critic_loss     | 0.00815  |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | -21.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 60       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | 1.02     |
# |    critic_loss     | 0.00935  |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | -21.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 60       |
# |    time_elapsed    | 190      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | 1.71     |
# |    critic_loss     | 0.00538  |
# |    ent_coef        | 0.0321   |
# |    ent_coef_loss   | -22      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 60       |
# |    time_elapsed    | 193      |
# |    total_timesteps | 11800    |
# | train/             |          |
# |    actor_loss      | 2.13     |
# |    critic_loss     | 0.0124   |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | -22.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11699    |
# ---------------------------------
# Num timesteps: 12000
# Best mean reward: -31.88 - Last mean reward per episode: -31.71
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 60       |
# |    time_elapsed    | 197      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | 2.62     |
# |    critic_loss     | 0.00499  |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | -22.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 60       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | 3.1      |
# |    critic_loss     | 0.00897  |
# |    ent_coef        | 0.0269   |
# |    ent_coef_loss   | -23.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 60       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | 3.78     |
# |    critic_loss     | 0.00599  |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -22.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 60       |
# |    time_elapsed    | 206      |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | 3.96     |
# |    critic_loss     | 0.0123   |
# |    ent_coef        | 0.0239   |
# |    ent_coef_loss   | -23.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 60       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | 4.44     |
# |    critic_loss     | 0.00808  |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | -23      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12699    |
# ---------------------------------
# Num timesteps: 13000
# Best mean reward: -31.71 - Last mean reward per episode: -31.42
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 60       |
# |    time_elapsed    | 213      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | 4.82     |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.0213   |
# |    ent_coef_loss   | -23.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 60       |
# |    time_elapsed    | 216      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | 5.74     |
# |    critic_loss     | 0.0116   |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -23.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 60       |
# |    time_elapsed    | 220      |
# |    total_timesteps | 13400    |
# | train/             |          |
# |    actor_loss      | 6.51     |
# |    critic_loss     | 0.0109   |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | -24.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 60       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | 7.28     |
# |    critic_loss     | 0.00828  |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | -23.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 60       |
# |    time_elapsed    | 226      |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | 7.45     |
# |    critic_loss     | 0.012    |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -24.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13699    |
# ---------------------------------
# Num timesteps: 14000
# Best mean reward: -31.42 - Last mean reward per episode: -31.47
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 60       |
# |    time_elapsed    | 229      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 8.21     |
# |    critic_loss     | 0.00688  |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -23.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 60       |
# |    time_elapsed    | 233      |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | 8.71     |
# |    critic_loss     | 0.0129   |
# |    ent_coef        | 0.015    |
# |    ent_coef_loss   | -24.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 60       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | 8.51     |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.0142   |
# |    ent_coef_loss   | -24.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 60       |
# |    time_elapsed    | 239      |
# |    total_timesteps | 14600    |
# | train/             |          |
# |    actor_loss      | 9.17     |
# |    critic_loss     | 0.0101   |
# |    ent_coef        | 0.0134   |
# |    ent_coef_loss   | -24.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 60       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | 10.4     |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.0126   |
# |    ent_coef_loss   | -25.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14699    |
# ---------------------------------
# Num timesteps: 15000
# Best mean reward: -31.42 - Last mean reward per episode: -31.39
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 60       |
# |    time_elapsed    | 246      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 10.2     |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | -24.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -31.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 60       |
# |    time_elapsed    | 249      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | 10.9     |
# |    critic_loss     | 0.0185   |
# |    ent_coef        | 0.0113   |
# |    ent_coef_loss   | -24.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15099    |
# ---------------------------------
# ...
# | train/             |          |
# |    actor_loss      | 22.5     |
# |    critic_loss     | 0.0135   |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 60       |
# |    time_elapsed    | 333      |
# |    total_timesteps | 20200    |
# | train/             |          |
# |    actor_loss      | 22.9     |
# |    critic_loss     | 0.0173   |
# |    ent_coef        | 0.00301  |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 60       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | 23.1     |
# |    critic_loss     | 0.0156   |
# |    ent_coef        | 0.00287  |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 60       |
# |    time_elapsed    | 339      |
# |    total_timesteps | 20600    |
# | train/             |          |
# |    actor_loss      | 23.4     |
# |    critic_loss     | 0.00653  |
# |    ent_coef        | 0.00274  |
# |    ent_coef_loss   | -13.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 60       |
# |    time_elapsed    | 343      |
# |    total_timesteps | 20800    |
# | train/             |          |
# |    actor_loss      | 24.3     |
# |    critic_loss     | 0.0136   |
# |    ent_coef        | 0.00262  |
# |    ent_coef_loss   | -13      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20699    |
# ---------------------------------
# Num timesteps: 21000
# Best mean reward: -31.39 - Last mean reward per episode: -32.95
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 60       |
# |    time_elapsed    | 346      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | 23.8     |
# |    critic_loss     | 0.0094   |
# |    ent_coef        | 0.0025   |
# |    ent_coef_loss   | -15      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 60       |
# |    time_elapsed    | 350      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | 25       |
# |    critic_loss     | 0.0209   |
# |    ent_coef        | 0.00239  |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 60       |
# |    time_elapsed    | 353      |
# |    total_timesteps | 21400    |
# | train/             |          |
# |    actor_loss      | 25       |
# |    critic_loss     | 0.0133   |
# |    ent_coef        | 0.00229  |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 60       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | 25.5     |
# |    critic_loss     | 0.0172   |
# |    ent_coef        | 0.00219  |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 60       |
# |    time_elapsed    | 360      |
# |    total_timesteps | 21800    |
# | train/             |          |
# |    actor_loss      | 25.8     |
# |    critic_loss     | 0.0141   |
# |    ent_coef        | 0.0021   |
# |    ent_coef_loss   | -8.19    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21699    |
# ---------------------------------
# Num timesteps: 22000
# Best mean reward: -31.39 - Last mean reward per episode: -32.84
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 60       |
# |    time_elapsed    | 363      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | 25.9     |
# |    critic_loss     | 0.0139   |
# |    ent_coef        | 0.00202  |
# |    ent_coef_loss   | -6.93    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 60       |
# |    time_elapsed    | 367      |
# |    total_timesteps | 22200    |
# | train/             |          |
# |    actor_loss      | 26.1     |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.00194  |
# |    ent_coef_loss   | -7.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 60       |
# |    time_elapsed    | 370      |
# |    total_timesteps | 22400    |
# | train/             |          |
# |    actor_loss      | 26.7     |
# |    critic_loss     | 0.0123   |
# |    ent_coef        | 0.00187  |
# |    ent_coef_loss   | -5.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 60       |
# |    time_elapsed    | 373      |
# |    total_timesteps | 22600    |
# | train/             |          |
# |    actor_loss      | 26.7     |
# |    critic_loss     | 0.0141   |
# |    ent_coef        | 0.0018   |
# |    ent_coef_loss   | -9.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 60       |
# |    time_elapsed    | 377      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 27.4     |
# |    critic_loss     | 0.0111   |
# |    ent_coef        | 0.00175  |
# |    ent_coef_loss   | -8.48    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22699    |
# ---------------------------------
# Num timesteps: 23000
# Best mean reward: -31.39 - Last mean reward per episode: -33.05
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -33      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 60       |
# |    time_elapsed    | 380      |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | 28       |
# |    critic_loss     | 0.0162   |
# |    ent_coef        | 0.00171  |
# |    ent_coef_loss   | -6.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 60       |
# |    time_elapsed    | 384      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | 28.9     |
# |    critic_loss     | 0.0105   |
# |    ent_coef        | 0.00167  |
# |    ent_coef_loss   | -3.74    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 60       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 23400    |
# | train/             |          |
# |    actor_loss      | 29.3     |
# |    critic_loss     | 0.0118   |
# |    ent_coef        | 0.00162  |
# |    ent_coef_loss   | -3.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 60       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | 29.2     |
# |    critic_loss     | 0.0136   |
# |    ent_coef        | 0.00157  |
# |    ent_coef_loss   | -4.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 60       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 23800    |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 0.0117   |
# |    ent_coef        | 0.00154  |
# |    ent_coef_loss   | -4.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23699    |
# ---------------------------------
# Num timesteps: 24000
# Best mean reward: -31.39 - Last mean reward per episode: -32.56
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 60       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 29.9     |
# |    critic_loss     | 0.0124   |
# |    ent_coef        | 0.0015   |
# |    ent_coef_loss   | -5.36    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 60       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 24200    |
# | train/             |          |
# |    actor_loss      | 30.2     |
# |    critic_loss     | 0.0206   |
# |    ent_coef        | 0.00146  |
# |    ent_coef_loss   | -3.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 60       |
# |    time_elapsed    | 404      |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | 31       |
# |    critic_loss     | 0.00694  |
# |    ent_coef        | 0.00143  |
# |    ent_coef_loss   | -6.86    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 60       |
# |    time_elapsed    | 408      |
# |    total_timesteps | 24600    |
# | train/             |          |
# |    actor_loss      | 31.2     |
# |    critic_loss     | 0.0212   |
# |    ent_coef        | 0.0014   |
# |    ent_coef_loss   | -2.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 60       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | 30.8     |
# |    critic_loss     | 0.0103   |
# |    ent_coef        | 0.00139  |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24699    |
# ---------------------------------
# Num timesteps: 25000
# Best mean reward: -31.39 - Last mean reward per episode: -32.77
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -32.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 60       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 31.1     |
# |    critic_loss     | 0.0151   |
# |    ent_coef        | 0.00138  |
# |    ent_coef_loss   | -4.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24899    |
# ---------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %%
def plot_results_both(log_folders, labels, title="Learning Curve"):
    fig = plt.figure(title)

    for log_folder, label in zip(log_folders, labels):
        x, y = ts2xy(load_results(log_folder), "timesteps")
        y = moving_average(y, window=50)
        x = x[len(x) - len(y) :]

        plt.plot(x, y, label=label)

    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.legend()
    plt.show()

# %%
log_folders = ['/content/logs_PPO','/content/logs_SAC']
labels = ["PPO", "SAC"]
plot_results_both(log_folders, labels)
