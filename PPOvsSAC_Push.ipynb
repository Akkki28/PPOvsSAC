# %% [markdown]
# <a href="https://colab.research.google.com/github/Akkki28/PPOvsSAC/blob/main/PPOvsSAC_Push.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
# !pip install gymnasium_robotics
# Out:
# Collecting gymnasium_robotics
#   Downloading gymnasium_robotics-1.3.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting mujoco<3.2.0,>=2.2.0 (from gymnasium_robotics)
#   Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.0.0)
# Collecting PettingZoo>=1.23.0 (from gymnasium_robotics)
#   Downloading pettingzoo-1.24.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: Jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (3.1.5)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (2.37.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.0.3->gymnasium_robotics) (3.0.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.12.0)
# Collecting glfw (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics)
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.1.9)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->gymnasium_robotics) (11.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.21.0)
# Downloading gymnasium_robotics-1.3.1-py3-none-any.whl (26.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 17.3 MB/s eta 0:00:00
# Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 25.3 MB/s eta 0:00:00
# Downloading pettingzoo-1.24.3-py3-none-any.whl (847 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 847.8/847.8 kB 36.3 MB/s eta 0:00:00
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: glfw, PettingZoo, mujoco, gymnasium_robotics
# Successfully installed PettingZoo-1.24.3 glfw-2.8.0 gymnasium_robotics-1.3.1 mujoco-3.1.6

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 6.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 39.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.5.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO,SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_dir = "./logs_PPO/"
os.makedirs(log_dir, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class SaveOnBestTrainingRewardCallback(BaseCallback):
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

gym.register_envs(gymnasium_robotics)
env = gym.make('FetchPushDense-v3')
env = Monitor(env, log_dir)
vec_env = make_vec_env(lambda: env, n_envs=1)

model1 = PPO("MultiInputPolicy",vec_env, verbose=1)
model1.learn(total_timesteps=25000,callback=callback)
model1.save("ppo")
# Out:
# Using cuda device
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -22.81
# Saving new best model to ./logs_PPO/best_model.zip
# Num timesteps: 2000
# Best mean reward: -22.81 - Last mean reward per episode: -22.83
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 198      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -22.81 - Last mean reward per episode: -22.68
# Saving new best model to ./logs_PPO/best_model.zip
# Num timesteps: 4000
# Best mean reward: -22.68 - Last mean reward per episode: -22.74
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 2           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004819477 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | -0.00448    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00462    |
# |    std                  | 0.995       |
# |    value_loss           | 6.14        |
# -----------------------------------------
# Num timesteps: 5000
# Best mean reward: -22.68 - Last mean reward per episode: -22.74
# Num timesteps: 6000
# Best mean reward: -22.68 - Last mean reward per episode: -22.62
# Saving new best model to ./logs_PPO/best_model.zip
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -22.6        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 192          |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0044497172 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.771        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00239     |
# |    std                  | 0.991        |
# |    value_loss           | 3.42         |
# ------------------------------------------
# Num timesteps: 7000
# Best mean reward: -22.62 - Last mean reward per episode: -22.67
# Num timesteps: 8000
# Best mean reward: -22.62 - Last mean reward per episode: -22.79
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 194         |
# |    iterations           | 4           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009101021 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.635       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00934    |
# |    std                  | 0.99        |
# |    value_loss           | 2.14        |
# -----------------------------------------
# Num timesteps: 9000
# Best mean reward: -22.62 - Last mean reward per episode: -22.76
# Num timesteps: 10000
# Best mean reward: -22.62 - Last mean reward per episode: -22.74
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -22.8        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 5            |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0114983795 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.958        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.02        |
# |    std                  | 0.988        |
# |    value_loss           | 2.02         |
# ------------------------------------------
# Num timesteps: 11000
# Best mean reward: -22.62 - Last mean reward per episode: -22.88
# Num timesteps: 12000
# Best mean reward: -22.62 - Last mean reward per episode: -22.84
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -22.8      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 196        |
# |    iterations           | 6          |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01803811 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.61      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.793      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.03      |
# |    std                  | 0.979      |
# |    value_loss           | 1.64       |
# ----------------------------------------
# Num timesteps: 13000
# Best mean reward: -22.62 - Last mean reward per episode: -22.82
# Num timesteps: 14000
# Best mean reward: -22.62 - Last mean reward per episode: -22.81
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 7           |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017804762 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.57       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.967       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0317     |
# |    std                  | 0.969       |
# |    value_loss           | 1.93        |
# -----------------------------------------
# Num timesteps: 15000
# Best mean reward: -22.62 - Last mean reward per episode: -22.78
# Num timesteps: 16000
# Best mean reward: -22.62 - Last mean reward per episode: -22.79
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 8           |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017773421 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.836       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.957       |
# |    value_loss           | 1.81        |
# -----------------------------------------
# Num timesteps: 17000
# Best mean reward: -22.62 - Last mean reward per episode: -22.67
# Num timesteps: 18000
# Best mean reward: -22.62 - Last mean reward per episode: -22.71
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -22.7      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 195        |
# |    iterations           | 9          |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01710375 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.48      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.661      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0261    |
# |    std                  | 0.947      |
# |    value_loss           | 1.23       |
# ----------------------------------------
# Num timesteps: 19000
# Best mean reward: -22.62 - Last mean reward per episode: -22.66
# Num timesteps: 20000
# Best mean reward: -22.62 - Last mean reward per episode: -22.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 10          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013698751 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.931       |
# |    value_loss           | 0.852       |
# -----------------------------------------
# Num timesteps: 21000
# Best mean reward: -22.62 - Last mean reward per episode: -22.68
# Num timesteps: 22000
# Best mean reward: -22.62 - Last mean reward per episode: -22.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 11          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015486929 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.368       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.924       |
# |    value_loss           | 0.64        |
# -----------------------------------------
# Num timesteps: 23000
# Best mean reward: -22.62 - Last mean reward per episode: -22.64
# Num timesteps: 24000
# Best mean reward: -22.62 - Last mean reward per episode: -22.73
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 12          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016414303 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.297       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.921       |
# |    value_loss           | 0.652       |
# -----------------------------------------
# Num timesteps: 25000
# Best mean reward: -22.62 - Last mean reward per episode: -22.81
# Num timesteps: 26000
# Best mean reward: -22.62 - Last mean reward per episode: -22.84
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -22.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 13          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011201628 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.904       |
# |    value_loss           | 0.429       |
# -----------------------------------------

# %%
log_dir2 = "./logs_SAC/"
os.makedirs(log_dir2, exist_ok=True)

# %%
callback2 = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir2)

env2 = gym.make('FetchPushDense-v3')
env2 = Monitor(env2, log_dir2)
vec_env2 = make_vec_env(lambda: env2, n_envs=1)

model2 = SAC("MultiInputPolicy",vec_env2, verbose=1)
model2.learn(total_timesteps=25000,callback=callback2)
model2.save("sac")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -21.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 93       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -5.31    |
# |    critic_loss     | 0.0491   |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 76       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -6.57    |
# |    critic_loss     | 0.0429   |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -21.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 72       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | -7.83    |
# |    critic_loss     | 0.0339   |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 68       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -8.99    |
# |    critic_loss     | 0.0422   |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -22.27
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 66       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.0389   |
# |    ent_coef        | 0.764    |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 66       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.0299   |
# |    ent_coef        | 0.719    |
# |    ent_coef_loss   | -2.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 66       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.0251   |
# |    ent_coef        | 0.677    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 64       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.0214   |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -3.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 64       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0181   |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -3.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# Num timesteps: 2000
# Best mean reward: -22.27 - Last mean reward per episode: -22.22
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 64       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.0149   |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 64       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.0431   |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -4.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 63       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.0178   |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -4.66    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 63       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.0292   |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -5.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 63       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -17.2    |
# |    critic_loss     | 0.0146   |
# |    ent_coef        | 0.445    |
# |    ent_coef_loss   | -5.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -22.22 - Last mean reward per episode: -22.26
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 63       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -17.7    |
# |    critic_loss     | 0.00959  |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -5.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 63       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -18      |
# |    critic_loss     | 0.00951  |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | -6.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 63       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.00919  |
# |    ent_coef        | 0.372    |
# |    ent_coef_loss   | -6.65    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 63       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.00791  |
# |    ent_coef        | 0.35     |
# |    ent_coef_loss   | -7.05    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 63       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.00751  |
# |    ent_coef        | 0.33     |
# |    ent_coef_loss   | -7.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3699     |
# ---------------------------------
# Num timesteps: 4000
# Best mean reward: -22.22 - Last mean reward per episode: -22.41
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 62       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 0.00583  |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -7.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 62       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 0.00514  |
# |    ent_coef        | 0.292    |
# |    ent_coef_loss   | -8.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 62       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 0.00475  |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -8.72    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 62       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 0.00446  |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | -9.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 62       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -18.8    |
# |    critic_loss     | 0.00525  |
# |    ent_coef        | 0.244    |
# |    ent_coef_loss   | -9.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# Num timesteps: 5000
# Best mean reward: -22.22 - Last mean reward per episode: -22.51
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 62       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -18.7    |
# |    critic_loss     | 0.004    |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | -9.89    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 62       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.00512  |
# |    ent_coef        | 0.217    |
# |    ent_coef_loss   | -10.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 62       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.0039   |
# |    ent_coef        | 0.204    |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 62       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -18.3    |
# |    critic_loss     | 0.00231  |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 62       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.00297  |
# |    ent_coef        | 0.181    |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5699     |
# ---------------------------------
# Num timesteps: 6000
# Best mean reward: -22.22 - Last mean reward per episode: -22.66
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 62       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.00303  |
# |    ent_coef        | 0.17     |
# |    ent_coef_loss   | -11.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 62       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.00205  |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 62       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.00268  |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -12.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 62       |
# |    time_elapsed    | 106      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.00278  |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 62       |
# |    time_elapsed    | 109      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.00156  |
# |    ent_coef        | 0.134    |
# |    ent_coef_loss   | -13.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# Num timesteps: 7000
# Best mean reward: -22.22 - Last mean reward per episode: -22.83
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 62       |
# |    time_elapsed    | 112      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.00183  |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 62       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.00181  |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | -14.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 62       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.00189  |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 62       |
# |    time_elapsed    | 122      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.00189  |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 62       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.00174  |
# |    ent_coef        | 0.0994   |
# |    ent_coef_loss   | -15.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7699     |
# ---------------------------------
# Num timesteps: 8000
# Best mean reward: -22.22 - Last mean reward per episode: -22.83
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 62       |
# |    time_elapsed    | 128      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.00123  |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 62       |
# |    time_elapsed    | 131      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | -14.3    |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.0881   |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 62       |
# |    time_elapsed    | 135      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.083    |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 62       |
# |    time_elapsed    | 138      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.00131  |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | -17.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 62       |
# |    time_elapsed    | 141      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.0736   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# Num timesteps: 9000
# Best mean reward: -22.22 - Last mean reward per episode: -22.83
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 62       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.0693   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 62       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.0653   |
# |    ent_coef_loss   | -18.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 62       |
# |    time_elapsed    | 150      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 0.000806 |
# |    ent_coef        | 0.0615   |
# |    ent_coef_loss   | -18.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 62       |
# |    time_elapsed    | 154      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 62       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.000795 |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | -19.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9699     |
# ---------------------------------
# Num timesteps: 10000
# Best mean reward: -22.22 - Last mean reward per episode: -22.70
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 62       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -10.4    |
# |    critic_loss     | 0.00085  |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -20      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 62       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -10      |
# |    critic_loss     | 0.000828 |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -20.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 61       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -9.52    |
# |    critic_loss     | 0.000893 |
# |    ent_coef        | 0.0456   |
# |    ent_coef_loss   | -20.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 61       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 10600    |
# | train/             |          |
# |    actor_loss      | -9.09    |
# |    critic_loss     | 0.00095  |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -21.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 61       |
# |    time_elapsed    | 174      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -8.58    |
# |    critic_loss     | 0.000943 |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -21.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10699    |
# ---------------------------------
# Num timesteps: 11000
# Best mean reward: -22.22 - Last mean reward per episode: -22.69
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 61       |
# |    time_elapsed    | 178      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -8.12    |
# |    critic_loss     | 0.00068  |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | -21.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 61       |
# |    time_elapsed    | 181      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -7.69    |
# |    critic_loss     | 0.000807 |
# |    ent_coef        | 0.0359   |
# |    ent_coef_loss   | -22.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 61       |
# |    time_elapsed    | 184      |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | -7.23    |
# |    critic_loss     | 0.000972 |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | -22.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 61       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -6.76    |
# |    critic_loss     | 0.000744 |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | -23      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 61       |
# |    time_elapsed    | 190      |
# |    total_timesteps | 11800    |
# | train/             |          |
# |    actor_loss      | -6.32    |
# |    critic_loss     | 0.000811 |
# |    ent_coef        | 0.03     |
# |    ent_coef_loss   | -23.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11699    |
# ---------------------------------
# Num timesteps: 12000
# Best mean reward: -22.22 - Last mean reward per episode: -22.70
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 61       |
# |    time_elapsed    | 194      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -5.9     |
# |    critic_loss     | 0.000759 |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 61       |
# |    time_elapsed    | 197      |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | -5.46    |
# |    critic_loss     | 0.000667 |
# |    ent_coef        | 0.0266   |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 61       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | -4.96    |
# |    critic_loss     | 0.000783 |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -24.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 61       |
# |    time_elapsed    | 204      |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | -4.58    |
# |    critic_loss     | 0.000688 |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -24.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 61       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | -4.08    |
# |    critic_loss     | 0.000739 |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | -24.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12699    |
# ---------------------------------
# Num timesteps: 13000
# Best mean reward: -22.22 - Last mean reward per episode: -22.87
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 61       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | -3.61    |
# |    critic_loss     | 0.00091  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -25.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 61       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -3.15    |
# |    critic_loss     | 0.000996 |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -25.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 61       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 13400    |
# | train/             |          |
# |    actor_loss      | -2.81    |
# |    critic_loss     | 0.000817 |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -26      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 61       |
# |    time_elapsed    | 221      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | -2.26    |
# |    critic_loss     | 0.00082  |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | -26.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 61       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | -1.87    |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.0165   |
# |    ent_coef_loss   | -26.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13699    |
# ---------------------------------
# Num timesteps: 14000
# Best mean reward: -22.22 - Last mean reward per episode: -22.84
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 61       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -1.4     |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -26.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 61       |
# |    time_elapsed    | 230      |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | -0.989   |
# |    critic_loss     | 0.000967 |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | -26.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 61       |
# |    time_elapsed    | 234      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -0.566   |
# |    critic_loss     | 0.00123  |
# |    ent_coef        | 0.0139   |
# |    ent_coef_loss   | -27.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 61       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 14600    |
# | train/             |          |
# |    actor_loss      | -0.178   |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.0131   |
# |    ent_coef_loss   | -27.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 61       |
# |    time_elapsed    | 240      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | 0.205    |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -27.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14699    |
# ---------------------------------
# Num timesteps: 15000
# Best mean reward: -22.22 - Last mean reward per episode: -22.91
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 61       |
# |    time_elapsed    | 244      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 0.678    |
# |    critic_loss     | 0.00138  |
# |    ent_coef        | 0.0116   |
# |    ent_coef_loss   | -27.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 61       |
# |    time_elapsed    | 247      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | 1.07     |
# |    critic_loss     | 0.00131  |
# |    ent_coef        | 0.011    |
# |    ent_coef_loss   | -27.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# ...
# | train/             |          |
# |    actor_loss      | 10.1     |
# |    critic_loss     | 0.00249  |
# |    ent_coef        | 0.00271  |
# |    ent_coef_loss   | -31.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 60       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 20200    |
# | train/             |          |
# |    actor_loss      | 10.5     |
# |    critic_loss     | 0.00362  |
# |    ent_coef        | 0.00256  |
# |    ent_coef_loss   | -30.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 60       |
# |    time_elapsed    | 334      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | 11       |
# |    critic_loss     | 0.00278  |
# |    ent_coef        | 0.00242  |
# |    ent_coef_loss   | -31      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 60       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 20600    |
# | train/             |          |
# |    actor_loss      | 11.3     |
# |    critic_loss     | 0.00401  |
# |    ent_coef        | 0.00228  |
# |    ent_coef_loss   | -30.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 60       |
# |    time_elapsed    | 341      |
# |    total_timesteps | 20800    |
# | train/             |          |
# |    actor_loss      | 11.7     |
# |    critic_loss     | 0.0018   |
# |    ent_coef        | 0.00215  |
# |    ent_coef_loss   | -31.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20699    |
# ---------------------------------
# Num timesteps: 21000
# Best mean reward: -22.22 - Last mean reward per episode: -22.88
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 60       |
# |    time_elapsed    | 345      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | 12       |
# |    critic_loss     | 0.00271  |
# |    ent_coef        | 0.00203  |
# |    ent_coef_loss   | -32.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 60       |
# |    time_elapsed    | 348      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | 12.3     |
# |    critic_loss     | 0.00428  |
# |    ent_coef        | 0.00192  |
# |    ent_coef_loss   | -31.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 60       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 21400    |
# | train/             |          |
# |    actor_loss      | 12.7     |
# |    critic_loss     | 0.00237  |
# |    ent_coef        | 0.00181  |
# |    ent_coef_loss   | -31.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 60       |
# |    time_elapsed    | 355      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | 13.1     |
# |    critic_loss     | 0.00302  |
# |    ent_coef        | 0.00171  |
# |    ent_coef_loss   | -29.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 60       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 21800    |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 0.00448  |
# |    ent_coef        | 0.00162  |
# |    ent_coef_loss   | -31.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21699    |
# ---------------------------------
# Num timesteps: 22000
# Best mean reward: -22.22 - Last mean reward per episode: -22.80
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 60       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | 13.6     |
# |    critic_loss     | 0.00253  |
# |    ent_coef        | 0.00153  |
# |    ent_coef_loss   | -30.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 60       |
# |    time_elapsed    | 364      |
# |    total_timesteps | 22200    |
# | train/             |          |
# |    actor_loss      | 14.1     |
# |    critic_loss     | 0.00253  |
# |    ent_coef        | 0.00145  |
# |    ent_coef_loss   | -30.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 60       |
# |    time_elapsed    | 368      |
# |    total_timesteps | 22400    |
# | train/             |          |
# |    actor_loss      | 14.4     |
# |    critic_loss     | 0.00318  |
# |    ent_coef        | 0.00137  |
# |    ent_coef_loss   | -32      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 60       |
# |    time_elapsed    | 371      |
# |    total_timesteps | 22600    |
# | train/             |          |
# |    actor_loss      | 14.6     |
# |    critic_loss     | 0.00236  |
# |    ent_coef        | 0.00129  |
# |    ent_coef_loss   | -30.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 60       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 15       |
# |    critic_loss     | 0.00352  |
# |    ent_coef        | 0.00122  |
# |    ent_coef_loss   | -29.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22699    |
# ---------------------------------
# Num timesteps: 23000
# Best mean reward: -22.22 - Last mean reward per episode: -22.80
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 60       |
# |    time_elapsed    | 378      |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | 15.3     |
# |    critic_loss     | 0.00885  |
# |    ent_coef        | 0.00115  |
# |    ent_coef_loss   | -30.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 60       |
# |    time_elapsed    | 381      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | 15.5     |
# |    critic_loss     | 0.0024   |
# |    ent_coef        | 0.00109  |
# |    ent_coef_loss   | -29.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 60       |
# |    time_elapsed    | 384      |
# |    total_timesteps | 23400    |
# | train/             |          |
# |    actor_loss      | 15.9     |
# |    critic_loss     | 0.00239  |
# |    ent_coef        | 0.00103  |
# |    ent_coef_loss   | -30.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 60       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | 16.1     |
# |    critic_loss     | 0.00514  |
# |    ent_coef        | 0.000975 |
# |    ent_coef_loss   | -31      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 60       |
# |    time_elapsed    | 391      |
# |    total_timesteps | 23800    |
# | train/             |          |
# |    actor_loss      | 16.6     |
# |    critic_loss     | 0.00228  |
# |    ent_coef        | 0.000923 |
# |    ent_coef_loss   | -29.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23699    |
# ---------------------------------
# Num timesteps: 24000
# Best mean reward: -22.22 - Last mean reward per episode: -22.89
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 60       |
# |    time_elapsed    | 394      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 16.8     |
# |    critic_loss     | 0.0026   |
# |    ent_coef        | 0.000873 |
# |    ent_coef_loss   | -29.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -22.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 60       |
# |    time_elapsed    | 397      |
# |    total_timesteps | 24200    |
# | train/             |          |
# |    actor_loss      | 17.1     |
# |    critic_loss     | 0.00522  |
# |    ent_coef        | 0.000827 |
# |    ent_coef_loss   | -28.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -23      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 60       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | 17.4     |
# |    critic_loss     | 0.00343  |
# |    ent_coef        | 0.000783 |
# |    ent_coef_loss   | -28      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -23      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 60       |
# |    time_elapsed    | 404      |
# |    total_timesteps | 24600    |
# | train/             |          |
# |    actor_loss      | 17.7     |
# |    critic_loss     | 0.00342  |
# |    ent_coef        | 0.000741 |
# |    ent_coef_loss   | -25.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -23      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 60       |
# |    time_elapsed    | 407      |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | 17.9     |
# |    critic_loss     | 0.00309  |
# |    ent_coef        | 0.000703 |
# |    ent_coef_loss   | -26.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24699    |
# ---------------------------------
# Num timesteps: 25000
# Best mean reward: -22.22 - Last mean reward per episode: -22.97
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -23      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 60       |
# |    time_elapsed    | 411      |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 18.2     |
# |    critic_loss     | 0.0035   |
# |    ent_coef        | 0.000667 |
# |    ent_coef_loss   | -26.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24899    |
# ---------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %%
def plot_results_both(log_folders, labels, title="Learning Curve"):
    fig = plt.figure(title)

    for log_folder, label in zip(log_folders, labels):
        x, y = ts2xy(load_results(log_folder), "timesteps")
        y = moving_average(y, window=50)
        x = x[len(x) - len(y) :]

        plt.plot(x, y, label=label)

    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.legend()
    plt.show()

# %%
log_folders = ['/content/logs_PPO','/content/logs_SAC']
labels = ["PPO", "SAC"]
plot_results_both(log_folders, labels)
