# %% [markdown]
# <a href="https://colab.research.google.com/github/Akkki28/PPOvsSAC/blob/main/PPOvsSAC_PickAndPlace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
# !pip install gymnasium_robotics
# Out:
# Collecting gymnasium_robotics
#   Downloading gymnasium_robotics-1.3.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting mujoco<3.2.0,>=2.2.0 (from gymnasium_robotics)
#   Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (1.0.0)
# Collecting PettingZoo>=1.23.0 (from gymnasium_robotics)
#   Downloading pettingzoo-1.24.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: Jinja2>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (3.1.5)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from gymnasium_robotics) (2.37.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0->gymnasium_robotics) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.0.3->gymnasium_robotics) (3.0.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (1.12.0)
# Collecting glfw (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics)
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.1.9)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->gymnasium_robotics) (11.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco<3.2.0,>=2.2.0->gymnasium_robotics) (3.21.0)
# Downloading gymnasium_robotics-1.3.1-py3-none-any.whl (26.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 31.4 MB/s eta 0:00:00
# Downloading mujoco-3.1.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 46.4 MB/s eta 0:00:00
# Downloading pettingzoo-1.24.3-py3-none-any.whl (847 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 847.8/847.8 kB 29.1 MB/s eta 0:00:00
# Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 9.9 MB/s eta 0:00:00
# Installing collected packages: glfw, PettingZoo, mujoco, gymnasium_robotics
# Successfully installed PettingZoo-1.24.3 glfw-2.8.0 gymnasium_robotics-1.3.1 mujoco-3.1.6

# %%
# !pip install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 5.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 55.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 58.9 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.5.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import gymnasium as gym
import gymnasium_robotics
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO,SAC
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

# %%
log_dir = "./logs_PPO/"
os.makedirs(log_dir, exist_ok=True)

# %%
from stable_baselines3.common.callbacks import BaseCallback
import numpy as np

class SaveOnBestTrainingRewardCallback(BaseCallback):
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

gym.register_envs(gymnasium_robotics)
env = gym.make('FetchPickAndPlaceDense-v3')
env = Monitor(env, log_dir)
vec_env = make_vec_env(lambda: env, n_envs=1)

model1 = PPO("MultiInputPolicy",vec_env, verbose=1)
model1.learn(total_timesteps=25000,callback=callback)
model1.save("ppo")
# Out:
# Using cpu device
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -26.18
# Saving new best model to ./logs_PPO/best_model.zip
# Num timesteps: 2000
# Best mean reward: -26.18 - Last mean reward per episode: -26.93
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -26.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 273      |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2048     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -26.18 - Last mean reward per episode: -27.00
# Num timesteps: 4000
# Best mean reward: -26.18 - Last mean reward per episode: -27.18
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -27.1        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 2            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044003394 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | -2.42e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.54         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00436     |
# |    std                  | 0.993        |
# |    value_loss           | 11.3         |
# ------------------------------------------
# Num timesteps: 5000
# Best mean reward: -26.18 - Last mean reward per episode: -26.83
# Num timesteps: 6000
# Best mean reward: -26.18 - Last mean reward per episode: -27.21
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -27         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006279515 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.36        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00237    |
# |    std                  | 0.992       |
# |    value_loss           | 9.22        |
# -----------------------------------------
# Num timesteps: 7000
# Best mean reward: -26.18 - Last mean reward per episode: -26.95
# Num timesteps: 8000
# Best mean reward: -26.18 - Last mean reward per episode: -26.87
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 50           |
# |    ep_rew_mean          | -26.9        |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 239          |
# |    iterations           | 4            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074527585 |
# |    clip_fraction        | 0.0771       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.512        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00756     |
# |    std                  | 0.988        |
# |    value_loss           | 6.28         |
# ------------------------------------------
# Num timesteps: 9000
# Best mean reward: -26.18 - Last mean reward per episode: -27.01
# Num timesteps: 10000
# Best mean reward: -26.18 - Last mean reward per episode: -27.83
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -27.6       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 5           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009338077 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00817    |
# |    std                  | 0.981       |
# |    value_loss           | 4.04        |
# -----------------------------------------
# Num timesteps: 11000
# Best mean reward: -26.18 - Last mean reward per episode: -28.43
# Num timesteps: 12000
# Best mean reward: -26.18 - Last mean reward per episode: -28.81
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -29.1       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 6           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010399748 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.974       |
# |    value_loss           | 5.16        |
# -----------------------------------------
# Num timesteps: 13000
# Best mean reward: -26.18 - Last mean reward per episode: -29.08
# Num timesteps: 14000
# Best mean reward: -26.18 - Last mean reward per episode: -28.89
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -28.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 7           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009639216 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00843    |
# |    std                  | 0.97        |
# |    value_loss           | 4.84        |
# -----------------------------------------
# Num timesteps: 15000
# Best mean reward: -26.18 - Last mean reward per episode: -28.50
# Num timesteps: 16000
# Best mean reward: -26.18 - Last mean reward per episode: -27.93
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -28.3       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 8           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014639033 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.849       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.96        |
# |    value_loss           | 2.55        |
# -----------------------------------------
# Num timesteps: 17000
# Best mean reward: -26.18 - Last mean reward per episode: -28.39
# Num timesteps: 18000
# Best mean reward: -26.18 - Last mean reward per episode: -28.22
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -28.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 228        |
# |    iterations           | 9          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01673818 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.48      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.61       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.949      |
# |    value_loss           | 1.63       |
# ----------------------------------------
# Num timesteps: 19000
# Best mean reward: -26.18 - Last mean reward per episode: -28.15
# Num timesteps: 20000
# Best mean reward: -26.18 - Last mean reward per episode: -28.26
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -28.7       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 10          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015088879 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.44       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.677       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.94        |
# |    value_loss           | 1.81        |
# -----------------------------------------
# Num timesteps: 21000
# Best mean reward: -26.18 - Last mean reward per episode: -28.29
# Num timesteps: 22000
# Best mean reward: -26.18 - Last mean reward per episode: -27.97
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -27.5      |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 226        |
# |    iterations           | 11         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01450941 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.39      |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.364      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0245    |
# |    std                  | 0.926      |
# |    value_loss           | 0.948      |
# ----------------------------------------
# Num timesteps: 23000
# Best mean reward: -26.18 - Last mean reward per episode: -28.01
# Num timesteps: 24000
# Best mean reward: -26.18 - Last mean reward per episode: -28.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -27.8       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 12          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017208293 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.33       |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.293       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.913       |
# |    value_loss           | 0.665       |
# -----------------------------------------
# Num timesteps: 25000
# Best mean reward: -26.18 - Last mean reward per episode: -27.99
# Num timesteps: 26000
# Best mean reward: -26.18 - Last mean reward per episode: -28.27
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -28.2       |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 226         |
# |    iterations           | 13          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013143327 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.27       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.897       |
# |    value_loss           | 0.767       |
# -----------------------------------------

# %%
log_dir2 = "./logs_SAC/"
os.makedirs(log_dir2, exist_ok=True)

# %%
callback2 = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir2)

env2 = gym.make('FetchPickAndPlaceDense-v3')
env2 = Monitor(env2, log_dir2)
vec_env2 = make_vec_env(lambda: env2, n_envs=1)

model2 = SAC("MultiInputPolicy",vec_env2, verbose=1)
model2.learn(total_timesteps=25000,callback=callback2)
model2.save("sac")
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -34.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 47       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | -5.12    |
# |    critic_loss     | 0.0736   |
# |    ent_coef        | 0.971    |
# |    ent_coef_loss   | -0.198   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -30.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 39       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -6.33    |
# |    critic_loss     | 0.0748   |
# |    ent_coef        | 0.914    |
# |    ent_coef_loss   | -0.603   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 35       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | -7.43    |
# |    critic_loss     | 0.0519   |
# |    ent_coef        | 0.861    |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 34       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -8.51    |
# |    critic_loss     | 0.0381   |
# |    ent_coef        | 0.811    |
# |    ent_coef_loss   | -1.41    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -27.44
# Saving new best model to ./logs_SAC/best_model.zip
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 32       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | -9.59    |
# |    critic_loss     | 0.0338   |
# |    ent_coef        | 0.764    |
# |    ent_coef_loss   | -1.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 32       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.0242   |
# |    ent_coef        | 0.719    |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 31       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0345   |
# |    ent_coef        | 0.677    |
# |    ent_coef_loss   | -2.62    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 31       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0221   |
# |    ent_coef        | 0.638    |
# |    ent_coef_loss   | -3.03    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 30       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.026    |
# |    ent_coef        | 0.601    |
# |    ent_coef_loss   | -3.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1699     |
# ---------------------------------
# Num timesteps: 2000
# Best mean reward: -27.44 - Last mean reward per episode: -28.49
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 30       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.0237   |
# |    ent_coef        | 0.566    |
# |    ent_coef_loss   | -3.83    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 30       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 0.0229   |
# |    ent_coef        | 0.533    |
# |    ent_coef_loss   | -4.23    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 30       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.502    |
# |    ent_coef_loss   | -4.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 30       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.0166   |
# |    ent_coef        | 0.473    |
# |    ent_coef_loss   | -5.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 29       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.0111   |
# |    ent_coef        | 0.445    |
# |    ent_coef_loss   | -5.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# Num timesteps: 3000
# Best mean reward: -27.44 - Last mean reward per episode: -28.22
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 30       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.0132   |
# |    ent_coef        | 0.419    |
# |    ent_coef_loss   | -5.84    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 29       |
# |    time_elapsed    | 107      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.0112   |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | -6.25    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 29       |
# |    time_elapsed    | 113      |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.0109   |
# |    ent_coef        | 0.372    |
# |    ent_coef_loss   | -6.67    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 29       |
# |    time_elapsed    | 120      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.35     |
# |    ent_coef_loss   | -7.04    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 29       |
# |    time_elapsed    | 126      |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.0057   |
# |    ent_coef        | 0.33     |
# |    ent_coef_loss   | -7.45    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3699     |
# ---------------------------------
# Num timesteps: 4000
# Best mean reward: -27.44 - Last mean reward per episode: -27.87
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 29       |
# |    time_elapsed    | 134      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.00503  |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -7.88    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 29       |
# |    time_elapsed    | 140      |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.00937  |
# |    ent_coef        | 0.293    |
# |    ent_coef_loss   | -8.27    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 29       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.00505  |
# |    ent_coef        | 0.275    |
# |    ent_coef_loss   | -8.64    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 29       |
# |    time_elapsed    | 155      |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.00567  |
# |    ent_coef        | 0.259    |
# |    ent_coef_loss   | -9.07    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 29       |
# |    time_elapsed    | 161      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.00507  |
# |    ent_coef        | 0.244    |
# |    ent_coef_loss   | -9.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# Num timesteps: 5000
# Best mean reward: -27.44 - Last mean reward per episode: -28.48
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 29       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.00478  |
# |    ent_coef        | 0.23     |
# |    ent_coef_loss   | -9.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 29       |
# |    time_elapsed    | 175      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.00319  |
# |    ent_coef        | 0.217    |
# |    ent_coef_loss   | -10.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 29       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 5400     |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0041   |
# |    ent_coef        | 0.204    |
# |    ent_coef_loss   | -10.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 29       |
# |    time_elapsed    | 189      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.00378  |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 29       |
# |    time_elapsed    | 196      |
# |    total_timesteps | 5800     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.00306  |
# |    ent_coef        | 0.181    |
# |    ent_coef_loss   | -11.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5699     |
# ---------------------------------
# Num timesteps: 6000
# Best mean reward: -27.44 - Last mean reward per episode: -28.93
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 29       |
# |    time_elapsed    | 203      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.00293  |
# |    ent_coef        | 0.171    |
# |    ent_coef_loss   | -12      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 29       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 6200     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.00511  |
# |    ent_coef        | 0.161    |
# |    ent_coef_loss   | -12.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 29       |
# |    time_elapsed    | 217      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.00186  |
# |    ent_coef        | 0.151    |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 29       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 6600     |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.00296  |
# |    ent_coef        | 0.142    |
# |    ent_coef_loss   | -13.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 29       |
# |    time_elapsed    | 231      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.00181  |
# |    ent_coef        | 0.134    |
# |    ent_coef_loss   | -13.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# Num timesteps: 7000
# Best mean reward: -27.44 - Last mean reward per episode: -28.51
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 29       |
# |    time_elapsed    | 238      |
# |    total_timesteps | 7000     |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.00206  |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 29       |
# |    time_elapsed    | 245      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.00281  |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | -14.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 29       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 7400     |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.00262  |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 28       |
# |    time_elapsed    | 262      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -11.9    |
# |    critic_loss     | 0.00276  |
# |    ent_coef        | 0.106    |
# |    ent_coef_loss   | -15      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 28       |
# |    time_elapsed    | 270      |
# |    total_timesteps | 7800     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.00159  |
# |    ent_coef        | 0.0994   |
# |    ent_coef_loss   | -15.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7699     |
# ---------------------------------
# Num timesteps: 8000
# Best mean reward: -27.44 - Last mean reward per episode: -28.96
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 28       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.00181  |
# |    ent_coef        | 0.0936   |
# |    ent_coef_loss   | -15.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 28       |
# |    time_elapsed    | 284      |
# |    total_timesteps | 8200     |
# | train/             |          |
# |    actor_loss      | -9.75    |
# |    critic_loss     | 0.0019   |
# |    ent_coef        | 0.0882   |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 28       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -9.57    |
# |    critic_loss     | 0.00191  |
# |    ent_coef        | 0.0831   |
# |    ent_coef_loss   | -16.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 28       |
# |    time_elapsed    | 299      |
# |    total_timesteps | 8600     |
# | train/             |          |
# |    actor_loss      | -9.5     |
# |    critic_loss     | 0.00282  |
# |    ent_coef        | 0.0782   |
# |    ent_coef_loss   | -17.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 28       |
# |    time_elapsed    | 306      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -8.66    |
# |    critic_loss     | 0.00238  |
# |    ent_coef        | 0.0737   |
# |    ent_coef_loss   | -17.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# Num timesteps: 9000
# Best mean reward: -27.44 - Last mean reward per episode: -29.25
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 28       |
# |    time_elapsed    | 314      |
# |    total_timesteps | 9000     |
# | train/             |          |
# |    actor_loss      | -8.34    |
# |    critic_loss     | 0.00184  |
# |    ent_coef        | 0.0694   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 28       |
# |    time_elapsed    | 321      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -7.93    |
# |    critic_loss     | 0.00218  |
# |    ent_coef        | 0.0654   |
# |    ent_coef_loss   | -18.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 28       |
# |    time_elapsed    | 328      |
# |    total_timesteps | 9400     |
# | train/             |          |
# |    actor_loss      | -7.45    |
# |    critic_loss     | 0.00135  |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -18.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 28       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -7.11    |
# |    critic_loss     | 0.00146  |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -19.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 28       |
# |    time_elapsed    | 343      |
# |    total_timesteps | 9800     |
# | train/             |          |
# |    actor_loss      | -6.75    |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.0546   |
# |    ent_coef_loss   | -19.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9699     |
# ---------------------------------
# Num timesteps: 10000
# Best mean reward: -27.44 - Last mean reward per episode: -28.38
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 28       |
# |    time_elapsed    | 350      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -5.82    |
# |    critic_loss     | 0.00275  |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -19.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 28       |
# |    time_elapsed    | 358      |
# |    total_timesteps | 10200    |
# | train/             |          |
# |    actor_loss      | -5.6     |
# |    critic_loss     | 0.00144  |
# |    ent_coef        | 0.0485   |
# |    ent_coef_loss   | -20.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 28       |
# |    time_elapsed    | 365      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -4.95    |
# |    critic_loss     | 0.00184  |
# |    ent_coef        | 0.0456   |
# |    ent_coef_loss   | -20.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 28       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 10600    |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.043    |
# |    ent_coef_loss   | -20.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 28       |
# |    time_elapsed    | 379      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -3.84    |
# |    critic_loss     | 0.00135  |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -21.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10699    |
# ---------------------------------
# Num timesteps: 11000
# Best mean reward: -27.44 - Last mean reward per episode: -28.01
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 28       |
# |    time_elapsed    | 386      |
# |    total_timesteps | 11000    |
# | train/             |          |
# |    actor_loss      | -4.1     |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | -21.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 28       |
# |    time_elapsed    | 393      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -3.11    |
# |    critic_loss     | 0.00201  |
# |    ent_coef        | 0.0359   |
# |    ent_coef_loss   | -22.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 28       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 11400    |
# | train/             |          |
# |    actor_loss      | -2.85    |
# |    critic_loss     | 0.00287  |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | -22.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 28       |
# |    time_elapsed    | 408      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -2.21    |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.0319   |
# |    ent_coef_loss   | -22.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 28       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 11800    |
# | train/             |          |
# |    actor_loss      | -1.85    |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.03     |
# |    ent_coef_loss   | -23.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11699    |
# ---------------------------------
# Num timesteps: 12000
# Best mean reward: -27.44 - Last mean reward per episode: -28.45
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 28       |
# |    time_elapsed    | 423      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -1.59    |
# |    critic_loss     | 0.00363  |
# |    ent_coef        | 0.0283   |
# |    ent_coef_loss   | -23.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 28       |
# |    time_elapsed    | 429      |
# |    total_timesteps | 12200    |
# | train/             |          |
# |    actor_loss      | -0.632   |
# |    critic_loss     | 0.00298  |
# |    ent_coef        | 0.0266   |
# |    ent_coef_loss   | -23.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 28       |
# |    time_elapsed    | 437      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | -0.134   |
# |    critic_loss     | 0.00357  |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -24.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 28       |
# |    time_elapsed    | 443      |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | 0.402    |
# |    critic_loss     | 0.00175  |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -24.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 28       |
# |    time_elapsed    | 451      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | 0.343    |
# |    critic_loss     | 0.00198  |
# |    ent_coef        | 0.0223   |
# |    ent_coef_loss   | -25      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12699    |
# ---------------------------------
# Num timesteps: 13000
# Best mean reward: -27.44 - Last mean reward per episode: -28.18
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 28       |
# |    time_elapsed    | 458      |
# |    total_timesteps | 13000    |
# | train/             |          |
# |    actor_loss      | 1.26     |
# |    critic_loss     | 0.00159  |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -25.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 28       |
# |    time_elapsed    | 465      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | 2.1      |
# |    critic_loss     | 0.00149  |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -25.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 28       |
# |    time_elapsed    | 472      |
# |    total_timesteps | 13400    |
# | train/             |          |
# |    actor_loss      | 2.58     |
# |    critic_loss     | 0.00141  |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -25.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 28       |
# |    time_elapsed    | 479      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | 3.24     |
# |    critic_loss     | 0.00153  |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | -26.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 28       |
# |    time_elapsed    | 487      |
# |    total_timesteps | 13800    |
# | train/             |          |
# |    actor_loss      | 4.06     |
# |    critic_loss     | 0.00263  |
# |    ent_coef        | 0.0165   |
# |    ent_coef_loss   | -27.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13699    |
# ---------------------------------
# Num timesteps: 14000
# Best mean reward: -27.44 - Last mean reward per episode: -28.30
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 28       |
# |    time_elapsed    | 493      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | 4.32     |
# |    critic_loss     | 0.00191  |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -27.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 28       |
# |    time_elapsed    | 500      |
# |    total_timesteps | 14200    |
# | train/             |          |
# |    actor_loss      | 4.38     |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | -27.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 28       |
# |    time_elapsed    | 507      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | 4.7      |
# |    critic_loss     | 0.00192  |
# |    ent_coef        | 0.0138   |
# |    ent_coef_loss   | -27.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 28       |
# |    time_elapsed    | 515      |
# |    total_timesteps | 14600    |
# | train/             |          |
# |    actor_loss      | 4.86     |
# |    critic_loss     | 0.0032   |
# |    ent_coef        | 0.013    |
# |    ent_coef_loss   | -28.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 28       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | 6.49     |
# |    critic_loss     | 0.00212  |
# |    ent_coef        | 0.0123   |
# |    ent_coef_loss   | -28.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14699    |
# ---------------------------------
# Num timesteps: 15000
# Best mean reward: -27.44 - Last mean reward per episode: -28.24
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 28       |
# |    time_elapsed    | 529      |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | 6.56     |
# |    critic_loss     | 0.00243  |
# |    ent_coef        | 0.0115   |
# |    ent_coef_loss   | -28.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 28       |
# |    time_elapsed    | 537      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | 6.93     |
# |    critic_loss     | 0.00329  |
# |    ent_coef        | 0.0109   |
# |    ent_coef_loss   | -29.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# ...
# | train/             |          |
# |    actor_loss      | 18.3     |
# |    critic_loss     | 0.00213  |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | -25      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 28       |
# |    time_elapsed    | 712      |
# |    total_timesteps | 20200    |
# | train/             |          |
# |    actor_loss      | 17.2     |
# |    critic_loss     | 0.00246  |
# |    ent_coef        | 0.00267  |
# |    ent_coef_loss   | -24.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.4    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 28       |
# |    time_elapsed    | 718      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | 18.7     |
# |    critic_loss     | 0.00493  |
# |    ent_coef        | 0.00253  |
# |    ent_coef_loss   | -23.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 28       |
# |    time_elapsed    | 726      |
# |    total_timesteps | 20600    |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 0.0046   |
# |    ent_coef        | 0.00241  |
# |    ent_coef_loss   | -23.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 28       |
# |    time_elapsed    | 733      |
# |    total_timesteps | 20800    |
# | train/             |          |
# |    actor_loss      | 18.4     |
# |    critic_loss     | 0.00249  |
# |    ent_coef        | 0.00229  |
# |    ent_coef_loss   | -24      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20699    |
# ---------------------------------
# Num timesteps: 21000
# Best mean reward: -27.44 - Last mean reward per episode: -28.98
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -29      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 28       |
# |    time_elapsed    | 740      |
# |    total_timesteps | 21000    |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 0.00387  |
# |    ent_coef        | 0.00217  |
# |    ent_coef_loss   | -22.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 28       |
# |    time_elapsed    | 748      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | 19.2     |
# |    critic_loss     | 0.00409  |
# |    ent_coef        | 0.00206  |
# |    ent_coef_loss   | -21      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 28       |
# |    time_elapsed    | 754      |
# |    total_timesteps | 21400    |
# | train/             |          |
# |    actor_loss      | 20.3     |
# |    critic_loss     | 0.00217  |
# |    ent_coef        | 0.00196  |
# |    ent_coef_loss   | -21      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.5    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 28       |
# |    time_elapsed    | 762      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 0.00368  |
# |    ent_coef        | 0.00186  |
# |    ent_coef_loss   | -20.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 28       |
# |    time_elapsed    | 769      |
# |    total_timesteps | 21800    |
# | train/             |          |
# |    actor_loss      | 20.9     |
# |    critic_loss     | 0.00245  |
# |    ent_coef        | 0.00177  |
# |    ent_coef_loss   | -19.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21699    |
# ---------------------------------
# Num timesteps: 22000
# Best mean reward: -27.44 - Last mean reward per episode: -28.60
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 28       |
# |    time_elapsed    | 776      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | 20.6     |
# |    critic_loss     | 0.00645  |
# |    ent_coef        | 0.00168  |
# |    ent_coef_loss   | -19.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 28       |
# |    time_elapsed    | 783      |
# |    total_timesteps | 22200    |
# | train/             |          |
# |    actor_loss      | 20.5     |
# |    critic_loss     | 0.00188  |
# |    ent_coef        | 0.0016   |
# |    ent_coef_loss   | -22.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.2    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 28       |
# |    time_elapsed    | 790      |
# |    total_timesteps | 22400    |
# | train/             |          |
# |    actor_loss      | 20.7     |
# |    critic_loss     | 0.00187  |
# |    ent_coef        | 0.00152  |
# |    ent_coef_loss   | -20.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.1    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 28       |
# |    time_elapsed    | 798      |
# |    total_timesteps | 22600    |
# | train/             |          |
# |    actor_loss      | 22.2     |
# |    critic_loss     | 0.00325  |
# |    ent_coef        | 0.00145  |
# |    ent_coef_loss   | -13.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 28       |
# |    time_elapsed    | 804      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 22       |
# |    critic_loss     | 0.00366  |
# |    ent_coef        | 0.00139  |
# |    ent_coef_loss   | -18.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22699    |
# ---------------------------------
# Num timesteps: 23000
# Best mean reward: -27.44 - Last mean reward per episode: -27.77
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 28       |
# |    time_elapsed    | 811      |
# |    total_timesteps | 23000    |
# | train/             |          |
# |    actor_loss      | 22.6     |
# |    critic_loss     | 0.00456  |
# |    ent_coef        | 0.00132  |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.8    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 28       |
# |    time_elapsed    | 818      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | 23.5     |
# |    critic_loss     | 0.00448  |
# |    ent_coef        | 0.00126  |
# |    ent_coef_loss   | -12.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 28       |
# |    time_elapsed    | 825      |
# |    total_timesteps | 23400    |
# | train/             |          |
# |    actor_loss      | 23.1     |
# |    critic_loss     | 0.00369  |
# |    ent_coef        | 0.00121  |
# |    ent_coef_loss   | -16.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 28       |
# |    time_elapsed    | 832      |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | 23.9     |
# |    critic_loss     | 0.00391  |
# |    ent_coef        | 0.00116  |
# |    ent_coef_loss   | -16      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 28       |
# |    time_elapsed    | 839      |
# |    total_timesteps | 23800    |
# | train/             |          |
# |    actor_loss      | 23.3     |
# |    critic_loss     | 0.00451  |
# |    ent_coef        | 0.00111  |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23699    |
# ---------------------------------
# Num timesteps: 24000
# Best mean reward: -27.44 - Last mean reward per episode: -27.98
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28      |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 28       |
# |    time_elapsed    | 846      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 22.7     |
# |    critic_loss     | 0.00373  |
# |    ent_coef        | 0.00106  |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 28       |
# |    time_elapsed    | 853      |
# |    total_timesteps | 24200    |
# | train/             |          |
# |    actor_loss      | 24.2     |
# |    critic_loss     | 0.00387  |
# |    ent_coef        | 0.00102  |
# |    ent_coef_loss   | -3.55    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -28.3    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 28       |
# |    time_elapsed    | 860      |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | 24.9     |
# |    critic_loss     | 0.00481  |
# |    ent_coef        | 0.001    |
# |    ent_coef_loss   | -0.976   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.9    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 28       |
# |    time_elapsed    | 868      |
# |    total_timesteps | 24600    |
# | train/             |          |
# |    actor_loss      | 24.8     |
# |    critic_loss     | 0.00553  |
# |    ent_coef        | 0.00098  |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.7    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 28       |
# |    time_elapsed    | 876      |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | 24.7     |
# |    critic_loss     | 0.00621  |
# |    ent_coef        | 0.000945 |
# |    ent_coef_loss   | -11.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24699    |
# ---------------------------------
# Num timesteps: 25000
# Best mean reward: -27.44 - Last mean reward per episode: -27.60
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -27.6    |
# |    success_rate    | 0        |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 28       |
# |    time_elapsed    | 882      |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | 25.4     |
# |    critic_loss     | 0.00564  |
# |    ent_coef        | 0.000909 |
# |    ent_coef_loss   | -8.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24899    |
# ---------------------------------

# %%
import matplotlib.pyplot as plt
import numpy as np
def moving_average(values, window):
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %%
def plot_results_both(log_folders, labels, title="Learning Curve"):
    fig = plt.figure(title)

    for log_folder, label in zip(log_folders, labels):
        x, y = ts2xy(load_results(log_folder), "timesteps")
        y = moving_average(y, window=50)
        x = x[len(x) - len(y) :]

        plt.plot(x, y, label=label)

    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.legend()
    plt.show()

# %%
log_folders = ['/content/logs_PPO','/content/logs_SAC']
labels = ["PPO", "SAC"]
plot_results_both(log_folders, labels)
